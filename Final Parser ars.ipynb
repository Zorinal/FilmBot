# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import csv
import pandas as pd
import numpy as np

# %%
def delit(string):
    string = string.replace(":","")
    string = string.replace("'","")
    string = string.replace('"',"")
    string = string[4:]
    string = string[:-1]
    return string

# %%
def get_reviews(number_quest):
    quest_link = f"https://otvet.mail.ru/{number_quest}"
    inner_html_code = str(urlopen(quest_link).read(),'utf-8') #read html
    inner_soup = BeautifulSoup(inner_html_code, "html.parser")
    inner_soup = inner_soup.find('script', {'type':'application/ld+json'})
    text = str(inner_soup.get_text()) # found block we convert to string, next step it's just work with string
    reviews_answers = list(re.findall(r'text\":\"[\\а-яА-ЯёЁ \d()\,\-!\."a-zA-Z\/]*,',text)) #first element - quest, second - review, third - best answer, another - answers
    sort_reviews_answers = list(map(delit, reviews_answers)) #del trash
    quest = str(list(re.findall(r'name":\"[а-яА-Я \d()?!]*\"\,\"text\"',text))) #found need info (quest, reviews etc)
    quest = list(re.findall(r'[а-яА-Я]{1,}',quest)) # to list for sort info
    final_quest =' '.join(quest)
    review = sort_reviews_answers[0]
    best_answer = sort_reviews_answers[1] # in mail the first is the best
    another = sort_reviews_answers[2:]
    final_answers = [final_quest, review,best_answer,another, quest_link]
    return final_answers

# %%
file = open("Текстовый файл….txt", "rb")
need_text = str(file.read())
all_quest = list(re.findall(r'question\/[\d]*',need_text))
unique_quest = list(set((all_quest)))
unique_quest
# Out:
# ['question/230548526',
#  'question/232059290',
#  'question/234187061',
#  'question/234325333',
#  'question/233860641',
#  'question/230090591',
#  'question/231862068',
#  'question/231902712',
#  'question/229574350',
#  'question/228498115',
#  'question/225363084',
#  'question/233730488',
#  'question/232358085',
#  'question/234901117',
#  'question/229358029',
#  'question/233005172',
#  'question/230311516',
#  'question/227919529',
#  'question/233427581',
#  'question/233208288',
#  'question/233053539',
#  'question/230498147',
#  'question/214369494',
#  'question/234073266',
#  'question/233636870',
#  'question/231198023',
#  'question/230980817',
#  'question/226524102',
#  'question/233306969',
#  'question/233821035',
#  'question/232736080',
#  'question/229433383',
#  'question/232699534',
#  'question/234770190',
#  'question/234100176',
#  'question/228558803',
#  'question/230570625',
#  'question/228864022',
#  'question/234916031',
#  'question/230981221',
#  'question/232250498',
#  'question/233462963',
#  'question/232189391',
#  'question/234846759',
#  'question/232963915',
#  'question/232869502',
#  'question/230659725',
#  'question/233520081',
#  'question/232889153',
#  'question/230363254',
#  'question/230007738',
#  'question/228261533',
#  'question/234137907',
#  'question/233519233',
#  'question/229997797',
#  'question/229814633',
#  'question/231148614',
#  'question/232795361',
#  'question/234492054',
#  'question/232615409',
#  'question/233364997',
#  'question/232547227',
#  'question/233133125',
#  'question/232420461',
#  'question/227745076',
#  'question/228230469',
#  'question/233738875',
#  'question/233579519',
#  'question/229014551',
#  'question/233051721',
#  'question/230625552',
#  'question/233620253',
#  'question/228426128',
#  'question/227946716',
#  'question/233099235',
#  'question/229441484',
#  'question/228500373',
#  'question/229893595',
#  'question/228073490',
#  'question/232528993',
#  'question/227606953',
#  'question/228991373',
#  'question/234619524',
#  'question/234341800',
#  'question/227711458',
#  'question/231744080',
#  'question/234242355',
#  'question/229458374',
#  'question/229390686',
#  'question/228268701',
#  'question/230863782',
#  'question/228812230',
#  'question/233635890',
#  'question/230840500',
#  'question/228584310',
#  'question/229991767',
#  'question/232985333',
#  'question/232255121',
#  'question/234544074',
#  'question/230033514',
#  'question/227874066',
#  'question/232113424',
#  'question/230561443',
#  'question/233389758',
#  'question/233899042',
#  'question/233949143',
#  'question/233289440',
#  'question/232713772',
#  'question/234600524',
#  'question/230952969',
#  'question/228475164',
#  'question/233293105',
#  'question/231419578',
#  'question/234180650',
#  'question/231593713',
#  'question/230420304',
#  'question/230248249',
#  'question/229168501',
#  'question/230513165',
#  'question/233586186',
#  'question/231930604',
#  'question/228597091',
#  'question/227806119',
#  'question/234476431',
#  'question/231838852',
#  'question/229377206',
#  'question/231869352',
#  'question/227859140',
#  'question/233054909',
#  'question/232748596',
#  'question/231595186',
#  'question/231098322',
#  'question/234768311',
#  'question/234129309',
#  'question/232558893',
#  'question/231209696',
#  'question/229394678',
#  'question/228913911',
#  'question/233336395',
#  'question/228131656',
#  'question/227432871',
#  'question/227746722',
#  'question/233256984',
#  'question/233951829',
#  'question/230128024',
#  'question/234643824',
#  'question/232714212',
#  'question/234877544',
#  'question/231595543',
#  'question/229616303',
#  'question/234092311',
#  'question/231896140',
#  'question/230028792',
#  'question/230059538',
#  'question/233041973',
#  'question/232615071',
#  'question/229507304',
#  'question/228221725',
#  'question/231438541',
#  'question/227589685',
#  'question/234351325',
#  'question/218881027',
#  'question/230034021',
#  'question/229349700',
#  'question/230114742',
#  'question/232308416',
#  'question/233172984',
#  'question/234431251',
#  'question/231209501',
#  'question/230825873',
#  'question/229714442',
#  'question/228786810',
#  'question/228531066',
#  'question/234864142',
#  'question/229185252',
#  'question/228238061',
#  'question/230611077',
#  'question/229940660',
#  'question/228960488',
#  'question/228952583',
#  'question/229846307',
#  'question/229441811',
#  'question/234112490',
#  'question/234729037',
#  'question/234210123',
#  'question/234575801',
#  'question/233968741',
#  'question/232535653',
#  'question/233298334',
#  'question/232003701',
#  'question/231605444',
#  'question/234015243',
#  'question/232151420',
#  'question/234703493',
#  'question/231423312',
#  'question/230940256',
#  'question/234270745',
#  'question/229467490',
#  'question/229184415',
#  'question/227636109',
#  'question/227458322',
#  'question/228753043',
#  'question/230368740',
#  'question/232926153',
#  'question/228965630',
#  'question/232009778',
#  'question/234631520',
#  'question/231788015',
#  'question/230990544',
#  'question/228320972',
#  'question/234199402',
#  'question/229078268',
#  'question/232938634',
#  'question/232594589',
#  'question/229054155',
#  'question/230400464',
#  'question/234534269',
#  'question/231532928',
#  'question/233195996',
#  'question/231322036',
#  'question/227651685',
#  'question/229192731',
#  'question/227628196',
#  'question/234879720',
#  'question/232966101',
#  'question/232397394',
#  'question/231084289',
#  'question/230314445',
#  'question/231737056',
#  'question/229569336',
#  'question/231034047',
#  'question/215912026',
#  'question/229658876',
#  'question/233719036',
#  'question/232857635',
#  'question/232938438',
#  'question/232245199',
#  'question/233788352',
#  'question/233086937',
#  'question/233228077',
#  'question/231232862',
#  'question/231544957',
#  'question/229611890',
#  'question/233360374',
#  'question/228368884',
#  'question/228401959',
#  'question/228560899',
#  'question/228392016',
#  'question/231178859',
#  'question/230873968',
#  'question/228337098',
#  'question/229380254',
#  'question/228640253',
#  'question/232961867',
#  'question/228956536',
#  'question/231647180',
#  'question/229137516',
#  'question/230395443',
#  'question/229697389',
#  'question/228147487',
#  'question/233639162',
#  'question/229501008',
#  'question/234702667',
#  'question/230054336',
#  'question/232420999',
#  'question/230033548',
#  'question/230437068',
#  'question/229943271',
#  'question/232761217',
#  'question/232720035',
#  'question/227763169',
#  'question/229346579',
#  'question/233235453',
#  'question/214356853',
#  'question/232135810',
#  'question/229792816',
#  'question/230023435',
#  'question/229340707',
#  'question/234431546',
#  'question/229461899',
#  'question/228774567',
#  'question/231348793',
#  'question/228031551',
#  'question/232678113',
#  'question/229445627',
#  'question/230674173',
#  'question/229316287',
#  'question/230765754',
#  'question/228971019',
#  'question/233079029',
#  'question/233501428',
#  'question/227591474',
#  'question/227671913',
#  'question/230328648',
#  'question/229266501',
#  'question/234065530',
#  'question/234422855',
#  'question/233251651',
#  'question/228998495',
#  'question/231203682',
#  'question/231688182',
#  'question/233236102',
#  'question/230685061',
#  'question/230084602',
#  'question/229713789',
#  'question/233776963',
#  'question/228428897',
#  'question/233933433',
#  'question/227289894',
#  'question/234088877',
#  'question/232767493',
#  'question/232301982',
#  'question/229408653',
#  'question/231187601',
#  'question/233449497',
#  'question/232441284',
#  'question/229093644',
#  'question/230962497',
#  'question/233835746',
#  'question/229591399',
#  'question/232723954',
#  'question/229368844',
#  'question/233036836',
#  'question/231025485',
#  'question/234181237',
#  'question/228190994',
#  'question/228220757',
#  'question/229966896',
#  'question/229475456',
#  'question/231965062',
#  'question/231043249',
#  'question/234210270',
#  'question/232102818',
#  'question/230256070',
#  'question/227527905',
#  'question/233239042',
#  'question/233230864',
#  'question/232006508',
#  'question/233052345',
#  'question/230475146',
#  'question/228905944',
#  'question/231148743',
#  'question/231213613',
#  'question/234934927',
#  'question/230124273',
#  'question/232488362',
#  'question/230523149',
#  'question/231951688',
#  'question/233357276',
#  'question/234372072',
#  'question/227351752',
#  'question/231149578',
#  'question/234233488',
#  'question/219209167',
#  'question/232620033',
#  'question/231577517',
#  'question/230506914',
#  'question/229267608',
#  'question/233273457',
#  'question/228945505',
#  'question/229768744',
#  'question/229347359',
#  'question/232859193',
#  'question/233474395',
#  'question/229368531',
#  'question/229519332',
#  'question/231423422',
#  'question/227754265',
#  'question/228309780',
#  'question/233911448',
#  'question/234554882',
#  'question/230038231',
#  'question/227669169',
#  'question/233997490',
#  'question/229319561',
#  'question/230939541',
#  'question/232979719',
#  'question/229730076',
#  'question/229822430',
#  'question/233124957',
#  'question/228047212',
#  'question/230066837',
#  'question/227712899',
#  'question/229830813',
#  'question/227512941',
#  'question/232290467',
#  'question/230050750',
#  'question/224838698',
#  'question/233576834',
#  'question/231362994',
#  'question/228572706',
#  'question/229510467',
#  'question/234137665',
#  'question/228796879',
#  'question/228097353',
#  'question/232320529',
#  'question/228145720',
#  'question/228647812',
#  'question/230139910',
#  'question/228069531',
#  'question/229880155',
#  'question/229830320',
#  'question/233709204',
#  'question/228429601',
#  'question/232309211',
#  'question/228324046',
#  'question/227794060',
#  'question/232047553',
#  'question/230933197',
#  'question/231931461',
#  'question/233278829',
#  'question/234693410',
#  'question/233055487',
#  'question/232558918',
#  'question/231896186',
#  'question/229667212',
#  'question/229822319',
#  'question/227969594',
#  'question/227892817',
#  'question/233085354',
#  'question/233830444',
#  'question/232241407',
#  'question/227478273',
#  'question/229363832',
#  'question/230736170',
#  'question/234392026',
#  'question/230552157',
#  'question/231185556',
#  'question/228300118',
#  'question/227943373',
#  'question/231897133',
#  'question/233378352',
#  'question/234797603',
#  'question/224700068',
#  'question/233843931',
#  'question/228723909',
#  'question/233985503',
#  'question/232058744',
#  'question/229582468',
#  'question/230816842',
#  'question/227622265',
#  'question/232391114',
#  'question/229744387',
#  'question/231034212',
#  'question/226006731',
#  'question/232938688',
#  'question/227808321',
#  'question/234733305',
#  'question/228934965',
#  'question/231908824',
#  'question/232147021',
#  'question/230290711',
#  'question/228360433',
#  'question/224425629',
#  'question/234195679',
#  'question/231976009',
#  'question/234092974',
#  'question/217870329',
#  'question/227548238',
#  'question/233268512',
#  'question/233295899',
#  'question/229404697',
#  'question/229379772',
#  'question/232192832',
#  'question/229313007',
#  'question/227662952',
#  'question/233863213',
#  'question/230525168',
#  'question/230740580',
#  'question/234878287',
#  'question/228615377',
#  'question/234092636',
#  'question/233494344',
#  'question/231843600',
#  'question/227853527',
#  'question/230981109',
#  'question/234388588',
#  'question/228361429',
#  'question/232985475',
#  'question/231958047',
#  'question/230376416',
#  'question/230990902',
#  'question/227350579',
#  'question/229798562',
#  'question/232206577',
#  'question/230199369',
#  'question/228280991',
#  'question/233194651',
#  'question/227351486',
#  'question/234744370',
#  'question/233428118',
#  'question/233378644',
#  'question/231130850',
#  'question/231749192',
#  'question/234226043',
#  'question/234501138',
#  'question/227558816',
#  'question/229385402',
#  'question/229517405',
#  'question/232353156',
#  'question/231277900',
#  'question/229035865',
#  'question/230647755',
#  'question/232610504',
#  'question/227626178',
#  'question/234655982',
#  'question/232810310',
#  'question/229452483',
#  'question/231288414',
#  'question/233655902',
#  'question/233387157',
#  'question/229339903',
#  'question/227727468',
#  'question/230114111',
#  'question/230139701',
#  'question/233629518',
#  'question/234689320',
#  'question/232976423',
#  'question/232388527',
#  'question/231899446',
#  'question/230141701',
#  'question/228386346',
#  'question/234385285',
#  'question/231261601',
#  'question/231026297',
#  'question/229427044',
#  'question/228245495',
#  'question/227557130',
#  'question/230045678',
#  'question/234833718',
#  'question/228161219',
#  'question/231252930',
#  'question/234518452',
#  'question/234338516',
#  'question/234686116',
#  'question/233427820',
#  'question/234362372',
#  'question/219991518',
#  'question/231653532',
#  'question/231906303',
#  'question/230525398',
#  'question/228918580',
#  'question/229982526',
#  'question/230990952',
#  'question/229733724',
#  'question/232433910',
#  'question/214157677',
#  'question/229213890',
#  'question/229819723',
#  'question/231080557',
#  'question/230205477',
#  'question/230186878',
#  'question/228878964',
#  'question/213316814',
#  'question/234251782',
#  'question/232296363',
#  'question/231920282',
#  'question/231832169',
#  'question/230914523',
#  'question/229970565',
#  'question/231968491',
#  'question/231471131',
#  'question/229920033',
#  'question/229598383',
#  'question/229143819',
#  'question/230304184',
#  'question/230352697',
#  'question/231900237',
#  'question/230715741',
#  'question/228793754',
#  'question/234849296',
#  'question/232836301',
#  'question/232052991',
#  'question/232381460',
#  'question/230611165',
#  'question/228443215',
#  'question/232255634',
#  'question/231044662',
#  'question/229575778',
#  'question/234773094',
#  'question/232439203',
#  'question/229674393',
#  'question/231993353',
#  'question/228264278',
#  'question/232433137',
#  'question/229687126',
#  'question/229009632',
#  'question/231906688',
#  'question/228650403',
#  'question/228818232',
#  'question/234705184',
#  'question/234351458',
#  'question/229909061',
#  'question/232720686',
#  'question/232432618',
#  'question/228307788',
#  'question/227652430',
#  'question/231862688',
#  'question/231342429',
#  'question/234800106',
#  'question/234164313',
#  'question/231968659',
#  'question/231377120',
#  'question/228939246',
#  'question/232851637',
#  'question/234304331',
#  'question/232345917',
#  'question/228966414',
#  'question/227925430',
#  'question/230426959',
#  'question/229704117',
#  'question/230556471',
#  'question/228969772',
#  'question/230916793',
#  'question/228119166',
#  'question/233792468',
#  'question/230770819',
#  'question/229403456',
#  'question/231390525',
#  'question/232910941',
#  'question/234661041',
#  'question/231229135',
#  'question/233215327',
#  'question/228972077',
#  'question/228635852',
#  'question/228609701',
#  'question/230883630',
#  'question/234373000',
#  'question/231156367',
#  'question/230169367',
#  'question/228340841',
#  'question/233184444',
#  'question/234659711',
#  'question/230454046',
#  'question/229730110',
#  'question/229266207',
#  'question/228301377',
#  'question/233055675',
#  'question/231922052',
#  'question/234591716',
#  'question/234761115',
#  'question/230214610',
#  'question/230133888',
#  'question/230722809',
#  'question/229664983',
#  'question/229413142',
#  'question/233838222',
#  'question/234584112',
#  'question/229591577',
#  'question/234251783',
#  'question/233833251',
#  'question/230909117',
#  'question/229630151',
#  'question/232752913',
#  'question/229584208',
#  'question/231254201',
#  'question/227621173',
#  'question/234099889',
#  'question/231455138',
#  'question/233218262',
#  'question/234021725',
#  'question/233775748',
#  'question/234174460',
#  'question/229500415',
#  'question/232759249',
#  'question/234671234',
#  'question/233920279',
#  'question/230639054',
#  'question/224264863',
#  'question/221158256',
#  'question/231055995',
#  'question/229443734',
#  'question/228523366',
#  'question/228827385',
#  'question/233082178',
#  'question/231836953',
#  'question/232858897',
#  'question/228815519',
#  'question/228966158',
#  'question/233035806',
#  'question/227949012',
#  'question/230275482',
#  'question/230030554',
#  'question/233054055',
#  'question/228745227',
#  'question/227849950',
#  'question/227599287',
#  'question/227621005',
#  'question/231721545',
#  'question/233276199',
#  'question/231513248',
#  'question/234534941',
#  'question/229898562',
#  'question/228967062',
#  'question/234694753',
#  'question/232924219',
#  'question/234682036',
#  'question/232341598',
#  'question/234322022',
#  'question/234450540',
#  'question/232784615',
#  'question/230110741',
#  'question/228765968',
#  'question/228340505',
#  'question/230752466',
#  'question/234751259',
#  'question/231894520',
#  'question/232048920',
#  'question/230325063',
#  'question/230920109',
#  'question/227588920',
#  'question/229999907',
#  'question/232888776',
#  'question/232734373',
#  'question/233028475',
#  'question/234417320',
#  'question/230167823',
#  'question/229293438',
#  'question/228835930',
#  'question/228969956',
#  'question/233710019',
#  'question/228344038',
#  'question/234243413',
#  'question/231338783',
#  'question/228248071',
#  'question/231995912',
#  'question/228582149',
#  'question/232971866',
#  'question/227994720',
#  'question/234778785',
#  'question/232318773',
#  'question/229490612',
#  'question/234016558',
#  'question/232457977',
#  'question/234728007',
#  'question/233521783',
#  'question/231224939',
#  'question/230333113',
#  'question/229978984',
#  'question/221945362',
#  'question/231979139',
#  'question/231296774',
#  'question/229009534',
#  'question/228395255',
#  'question/229543103',
#  'question/227868837',
#  'question/230534558',
#  'question/234806060',
#  'question/233865363',
#  'question/230758378',
#  'question/231966840',
#  'question/229219561',
#  'question/232459427',
#  'question/228509586',
#  'question/229511164',
#  'question/228360596',
#  'question/232621023',
#  'question/227644343',
#  'question/227986619',
#  'question/230562862',
#  'question/231249309',
#  'question/234134867',
#  'question/227790461',
#  'question/231860158',
#  'question/233720979',
#  'question/232355043',
#  'question/229784535',
#  'question/232263213',
#  'question/228054163',
#  'question/228805297',
#  'question/225900792',
#  'question/230692674',
#  'question/229637731',
#  'question/229295199',
#  'question/231954767',
#  'question/229779134',
#  'question/228494298',
#  'question/231077608',
#  'question/228332597',
#  'question/229224093',
#  'question/228377113',
#  'question/229506547',
#  'question/228220172',
#  'question/231895537',
#  'question/234001715',
#  'question/234039368',
#  'question/228537135',
#  'question/233848788',
#  'question/233263560',
#  'question/231006132',
#  'question/231900641',
#  'question/230086199',
#  'question/231098512',
#  'question/233515700',
#  'question/231145611',
#  'question/231371816',
#  'question/228785350',
#  'question/232617156',
#  'question/233911847',
#  'question/230139592',
#  'question/233679016',
#  'question/230856487',
#  'question/230333303',
#  'question/234121089',
#  'question/228632507',
#  'question/228491230',
#  'question/227790355',
#  'question/213669597',
#  'question/213799845',
#  'question/232164916',
#  'question/233681671',
#  'question/229333520',
#  'question/231273127',
#  'question/234933231',
#  'question/231543400',
#  'question/232793980',
#  'question/231984832',
#  'question/229882395',
#  'question/231808085',
#  'question/229397736',
#  'question/234175623',
#  'question/230924123',
#  'question/231567189',
#  'question/228218859',
#  'question/225428542',
#  'question/231907202',
#  'question/230138228',
#  'question/227876921',
#  'question/232168863',
#  'question/233676430',
#  'question/228149576',
#  'question/228184252',
#  'question/231388949',
#  'question/233484578',
#  'question/234252660',
#  'question/231603873',
#  'question/229391354',
#  'question/231405762',
#  'question/230041245',
#  'question/228132813',
#  'question/229890418',
#  'question/228977476',
#  'question/231442549',
#  'question/230061846',
#  'question/228508509',
#  'question/234937021',
#  'question/228265730',
#  'question/233722800',
#  'question/230307989',
#  'question/231907577',
#  'question/229841497',
#  'question/214122277',
#  'question/233231386',
#  'question/232215801',
#  'question/232345930',
#  'question/233865952',
#  'question/228500940',
#  'question/229858487',
#  'question/234880866',
#  'question/228492306',
#  'question/228395386',
#  'question/228259423',
#  'question/233172849',
#  'question/232509228',
#  'question/230533449',
#  'question/229445173',
#  'question/229019811',
#  'question/231789214',
#  'question/232072863',
#  'question/231196256',
#  'question/234612746',
#  'question/232343892',
#  'question/227079908',
#  'question/230011611',
#  'question/230031382',
#  'question/229645219',
#  'question/234281214',
#  'question/234919314',
#  'question/230780928',
#  'question/234461125',
#  'question/231649292',
#  'question/216279364',
#  'question/229139726',
#  'question/228160944',
#  'question/230173464',
#  'question/219690050',
#  'question/227743510',
#  'question/232961957',
#  'question/230563104',
#  'question/231190986',
#  'question/229926091',
#  'question/230446212',
#  'question/232965396',
#  'question/229500530',
#  'question/229603283',
#  'question/229425186',
#  'question/229688789',
#  'question/229048121',
#  'question/232249587',
#  'question/233400692',
#  'question/234692396',
#  'question/234520430',
#  'question/232422038',
#  'question/233077121',
#  'question/233406516',
#  'question/233263189',
#  'question/231401913',
#  'question/231886079',
#  'question/230877283',
#  'question/230657676',
#  'question/230171211',
#  'question/232127511',
#  'question/229747351',
#  'question/230408179',
#  'question/232025746',
#  'question/227795913',
#  'question/227958399',
#  'question/234221437',
#  'question/230767797',
#  'question/233018105',
#  'question/232231914',
#  'question/230537611',
#  'question/233666126',
#  'question/229267635',
#  'question/234502457',
#  'question/233236803',
#  'question/228479263',
#  'question/232639483',
#  'question/233421337',
#  'question/233411757',
#  'question/230892230',
#  'question/231635933',
#  'question/231247762',
#  'question/230087249',
#  'question/233651094',
#  'question/234407687',
#  'question/229786767',
#  'question/227452627',
#  'question/232229259',
#  'question/233727435',
#  'question/231258761',
#  'question/231193294',
#  'question/229672682',
#  'question/233236256',
#  'question/231875119',
#  'question/231646197',
#  'question/231015230',
#  'question/234185603',
#  'question/234012625',
#  'question/232655369',
#  'question/228046926',
#  'question/233413039',
#  'question/234878477',
#  'question/227891212',
#  'question/232077016',
#  'question/230655461',
#  'question/232836936',
#  'question/227643704',
#  'question/229011938',
#  'question/231121745',
#  'question/232124437',
#  'question/229257990',
#  'question/228639378',
#  'question/231996769',
#  'question/231632584',
#  'question/228009286',
#  'question/232849794',
#  'question/227993696',
#  'question/227607955',
#  'question/228431245',
#  'question/229129415',
#  'question/231208667',
#  'question/229584853',
#  'question/232189733',
#  'question/232975968',
#  'question/231355782',
#  'question/228627398',
#  'question/234618719',
#  'question/229412508',
#  'question/230529931',
#  'question/230174132',
#  'question/233273138',
#  'question/232813287',
#  'question/231724362',
#  'question/234662163',
#  'question/231776078',
#  'question/228813734',
#  'question/229694292',
#  'question/233352485',
#  'question/232965750',
#  'question/229275905',
#  'question/233916379',
#  'question/229023230',
#  'question/228325760',
#  'question/228960094',
#  'question/234905165',
#  'question/233620732',
#  'question/219742366',
#  'question/231062297',
#  'question/228593536',
#  ...]

# %%
for question in unique_quest:
    quest_link = f'https://otvet.mail.ru/{question}' 
    inner_html_code = str(urlopen(quest_link).read(),'utf-8') #По факту Арс засунь этот весь код в функцию, и тут ток ссылку менять
    inner_soup = BeautifulSoup(inner_html_code, "html.parser")
    inner_soup = inner_soup.find('script', {'type':'application/ld+json'})
    text = str(inner_soup.get_text()) # found block we convert to string, next step it's just work with string
    def delit(string):
        string = string.replace(":","")
        string = string.replace("'","")
        string = string.replace('"',"")
        string = string[4:]
        string = string[:-1]
        return string
    reviews_answers = list(re.findall(r'text\":\"[\\а-яА-ЯёЁ \d()\,\-!\."a-zA-Z\/]*,',text)) #first element - quest, second - review, third - best answer, another - answers
    sort_reviews_answers = list(map(delit, reviews_answers)) #del trash
    quest = str(list(re.findall(r'name":\"[а-яА-Я \d()?!]*\"\,\"text\"',text)))
    quest = list(re.findall(r'[а-яА-Я]{1,}',quest))
    final_quest =' '.join(quest)
    try:
        review = sort_reviews_answers[0]
        except:
        best_answer = '0'
    try:
        best_answer = sort_reviews_answers[1] # в mail вопросах наилучший самый первый
    except:
        best_answer = '0'
    another = sort_reviews_answers[2:]
    sort_reviews_answers
    #text\":\"[а-яА-Я \d()]*\"
    #
    header = ['Quest','Review','Popular','Another','Questslink']
    data = [final_quest, review, best_answer, another, quest_link]
    with open('Mailreview.csv', 'w', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerow(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 19
#      17 quest = list(re.findall(r'[а-яА-Я]{1,}',quest))
#      18 final_quest =' '.join(quest)
# ---> 19 review = sort_reviews_answers[0]
#      20 try:
#      21     best_answer = sort_reviews_answers[1] # в mail вопросах наилучший самый первый
#
# IndexError: list index out of range
