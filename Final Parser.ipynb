# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import csv
import pandas as pd
import numpy as np

# %%
def delit(string):
    string = string.replace(":","")
    string = string.replace("'","")
    string = string.replace('"',"")
    string = string[4:]
    string = string[:-1]
    return string

# %%
def get_reviews(number_quest):
    quest_link = f"https://otvet.mail.ru/{number_quest}"
    inner_html_code = str(urlopen(quest_link).read(),'utf-8') #read html
    inner_soup = BeautifulSoup(inner_html_code, "html.parser")
    inner_soup = inner_soup.find('script', {'type':'application/ld+json'})
    text = str(inner_soup.get_text()) # found block we convert to string, next step it's just work with string
    reviews_answers = list(re.findall(r'text\":\"[\\а-яА-ЯёЁ \d()\,\-!\."a-zA-Z\/]*,',text)) #first element - quest, second - review, third - best answer, another - answers
    sort_reviews_answers = list(map(delit, reviews_answers)) #del trash
    quest = str(list(re.findall(r'name":\"[а-яА-Я \d()?!]*\"\,\"text\"',text))) #found need info (quest, reviews etc)
    quest = list(re.findall(r'[а-яА-Я]{1,}',quest)) # to list for sort info
    final_quest =' '.join(quest)
    review = sort_reviews_answers[0]
    best_answer = sort_reviews_answers[1] # in mail the first is the best
    another = sort_reviews_answers[2:]
    final_answers = [final_quest, review,best_answer,another, quest_link]
    return final_answers

# %%
file = open("/home/dimon/Рабочий стол/Текстовый файл….txt", "rb")
need_text = str(file.read())
all_quest = list(re.findall(r'question\/[\d]*',need_text))
unique_quest = list(set((all_quest)))
unique_quest
# Out:
# ['question/234372072',
#  'question/228264278',
#  'question/232258796',
#  'question/231907202',
#  'question/230920109',
#  'question/229129415',
#  'question/232263213',
#  'question/231249309',
#  'question/229275905',
#  'question/234053266',
#  'question/231121745',
#  'question/234351325',
#  'question/234187061',
#  'question/231968659',
#  'question/230030554',
#  'question/230256070',
#  'question/230981221',
#  'question/224700068',
#  'question/230231267',
#  'question/229704117',
#  'question/229267608',
#  'question/227849950',
#  'question/228265730',
#  'question/234233488',
#  'question/228933096',
#  'question/228325760',
#  'question/228498115',
#  'question/227943373',
#  'question/233521783',
#  'question/228537135',
#  'question/231055995',
#  'question/230255303',
#  'question/228631226',
#  'question/230114742',
#  'question/229768067',
#  'question/232127511',
#  'question/229048121',
#  'question/234417320',
#  'question/234092311',
#  'question/231185556',
#  'question/234127349',
#  'question/234584112',
#  'question/234600524',
#  'question/227289894',
#  'question/233236256',
#  'question/231208667',
#  'question/227754265',
#  'question/233018105',
#  'question/230166802',
#  'question/229406457',
#  'question/229333520',
#  'question/226543192',
#  'question/230126585',
#  'question/229339903',
#  'question/234251782',
#  'question/231254201',
#  'question/227711458',
#  'question/227727468',
#  'question/233051721',
#  'question/232059290',
#  'question/234232623',
#  'question/234770474',
#  'question/232836301',
#  'question/232617156',
#  'question/232164916',
#  'question/229630151',
#  'question/227512941',
#  'question/230376416',
#  'question/234554882',
#  'question/234806060',
#  'question/234768311',
#  'question/228069531',
#  'question/234015243',
#  'question/233328060',
#  'question/227993696',
#  'question/231541893',
#  'question/228221725',
#  'question/229011938',
#  'question/229997797',
#  'question/234039368',
#  'question/233708326',
#  'question/228395255',
#  'question/228573234',
#  'question/227946716',
#  'question/230061846',
#  'question/231896140',
#  'question/230352697',
#  'question/232594589',
#  'question/228031551',
#  'question/234461125',
#  'question/233184444',
#  'question/231037910',
#  'question/234797603',
#  'question/234643824',
#  'question/232420461',
#  'question/230990902',
#  'question/227591474',
#  'question/227746722',
#  'question/234210270',
#  'question/232961957',
#  'question/232759249',
#  'question/232523747',
#  'question/233082257',
#  'question/232006508',
#  'question/233054055',
#  'question/232345930',
#  'question/233387157',
#  'question/234575801',
#  'question/231653532',
#  'question/231187601',
#  'question/231362994',
#  'question/227350579',
#  'question/233427581',
#  'question/230883630',
#  'question/228765968',
#  'question/228300118',
#  'question/230139910',
#  'question/233738875',
#  'question/231749192',
#  'question/233856921',
#  'question/230529931',
#  'question/229714442',
#  'question/233177255',
#  'question/229506547',
#  'question/229603283',
#  'question/232509021',
#  'question/230085564',
#  'question/234934927',
#  'question/233576834',
#  'question/233054909',
#  'question/231098512',
#  'question/230041245',
#  'question/232966101',
#  'question/233077121',
#  'question/230506914',
#  'question/229920033',
#  'question/229703581',
#  'question/232224140',
#  'question/228998495',
#  'question/227966815',
#  'question/233333697',
#  'question/230408179',
#  'question/229348394',
#  'question/227079908',
#  'question/233911847',
#  'question/227652430',
#  'question/230248249',
#  'question/228813734',
#  'question/234309316',
#  'question/230023435',
#  'question/232985475',
#  'question/230038231',
#  'question/234879720',
#  'question/227808321',
#  'question/234591716',
#  'question/231543400',
#  'question/234502457',
#  'question/221945362',
#  'question/229882395',
#  'question/231273127',
#  'question/233378352',
#  'question/229009632',
#  'question/233406516',
#  'question/230533449',
#  'question/228019806',
#  'question/231196256',
#  'question/233848788',
#  'question/231190986',
#  'question/221158256',
#  'question/233195996',
#  'question/228259423',
#  'question/227432871',
#  'question/219209167',
#  'question/231119306',
#  'question/234362372',
#  'question/230924123',
#  'question/231907577',
#  'question/228969956',
#  'question/228523366',
#  'question/227878871',
#  'question/227452627',
#  'question/234744370',
#  'question/229664983',
#  'question/233035806',
#  'question/229582468',
#  'question/230802986',
#  'question/234341800',
#  'question/228864022',
#  'question/232797432',
#  'question/232077016',
#  'question/230655461',
#  'question/234429132',
#  'question/232189391',
#  'question/229500415',
#  'question/229517405',
#  'question/225363084',
#  'question/233055487',
#  'question/233036836',
#  'question/233427820',
#  'question/231145611',
#  'question/229779134',
#  'question/229408653',
#  'question/231125617',
#  'question/234373000',
#  'question/232047553',
#  'question/231401913',
#  'question/229257990',
#  'question/229023230',
#  'question/230437068',
#  'question/229014551',
#  'question/233797413',
#  'question/230139701',
#  'question/232963915',
#  'question/233235453',
#  'question/233792468',
#  'question/229943271',
#  'question/230087249',
#  'question/233579519',
#  'question/230916793',
#  'question/228360433',
#  'question/228934965',
#  'question/228531066',
#  'question/213316814',
#  'question/231959111',
#  'question/229490612',
#  'question/231388486',
#  'question/229574350',
#  'question/228429601',
#  'question/229433383',
#  'question/229316287',
#  'question/231738684',
#  'question/231951688',
#  'question/228969772',
#  'question/231247762',
#  'question/228650403',
#  'question/230328648',
#  'question/231869352',
#  'question/214122277',
#  'question/234751259',
#  'question/233494344',
#  'question/233657902',
#  'question/234693410',
#  'question/227671913',
#  'question/229461899',
#  'question/227712899',
#  'question/229266501',
#  'question/231838852',
#  'question/229427044',
#  'question/228991373',
#  'question/232241407',
#  'question/232979719',
#  'question/233911448',
#  'question/229674393',
#  'question/219991518',
#  'question/228759546',
#  'question/231213613',
#  'question/228384347',
#  'question/229519332',
#  'question/230980817',
#  'question/231603873',
#  'question/232888776',
#  'question/228426128',
#  'question/229898562',
#  'question/228377113',
#  'question/232072863',
#  'question/228268701',
#  'question/227783502',
#  'question/233759395',
#  'question/234901117',
#  'question/234221437',
#  'question/234092974',
#  'question/232889153',
#  'question/231193294',
#  'question/230825873',
#  'question/229467490',
#  'question/233005172',
#  'question/234325333',
#  'question/228945505',
#  'question/231900641',
#  'question/232381460',
#  'question/231322036',
#  'question/230454046',
#  'question/218881027',
#  'question/234504515',
#  'question/229385402',
#  'question/234017505',
#  'question/227806119',
#  'question/230244127',
#  'question/228815519',
#  'question/229543103',
#  'question/228395386',
#  'question/228376407',
#  'question/229404697',
#  'question/232391114',
#  'question/228967062',
#  'question/232124437',
#  'question/231906303',
#  'question/233501428',
#  'question/231006132',
#  'question/229645219',
#  'question/233872826',
#  'question/233230864',
#  'question/233218262',
#  'question/232058744',
#  'question/233263189',
#  'question/231776078',
#  'question/230877283',
#  'question/234104800',
#  'question/234933231',
#  'question/232151420',
#  'question/229822430',
#  'question/228727994',
#  'question/230647755',
#  'question/229137516',
#  'question/231738858',
#  'question/234037130',
#  'question/234655982',
#  'question/228431245',
#  'question/233357276',
#  'question/231062297',
#  'question/227540809',
#  'question/231355782',
#  'question/229266207',
#  'question/227919529',
#  'question/232332036',
#  'question/232858897',
#  'question/234520430',
#  'question/228913911',
#  'question/228428897',
#  'question/225428542',
#  'question/231224939',
#  'question/227607955',
#  'question/232976423',
#  'question/233413039',
#  'question/232752913',
#  'question/228560899',
#  'question/230752466',
#  'question/234185603',
#  'question/233352485',
#  'question/228952583',
#  'question/232938634',
#  'question/232433910',
#  'question/231098322',
#  'question/234937021',
#  'question/234877544',
#  'question/231996769',
#  'question/230033548',
#  'question/234492054',
#  'question/234100176',
#  'question/230952969',
#  'question/233085354',
#  'question/228337098',
#  'question/232748596',
#  'question/232708718',
#  'question/230169367',
#  'question/234534269',
#  'question/232433137',
#  'question/227949226',
#  'question/227669169',
#  'question/234919314',
#  'question/228977476',
#  'question/234304331',
#  'question/230525398',
#  'question/228218859',
#  'question/230537611',
#  'question/229902460',
#  'question/232767493',
#  'question/230034021',
#  'question/234431251',
#  'question/232793980',
#  'question/233082178',
#  'question/230128024',
#  'question/229035865',
#  'question/233268512',
#  'question/233484578',
#  'question/234322022',
#  'question/232420999',
#  'question/233194651',
#  'question/232795361',
#  'question/231875119',
#  'question/230498147',
#  'question/229819723',
#  'question/234778785',
#  'question/228637732',
#  'question/224425629',
#  'question/230066837',
#  'question/232457977',
#  'question/231920282',
#  'question/231832169',
#  'question/229658876',
#  'question/234195679',
#  'question/232974369',
#  'question/234137907',
#  'question/228131656',
#  'question/229411409',
#  'question/229880155',
#  'question/231015230',
#  'question/229792816',
#  'question/233289440',
#  'question/229340707',
#  'question/229441484',
#  'question/233079029',
#  'question/234618719',
#  'question/233364997',
#  'question/229786767',
#  'question/230892230',
#  'question/231148743',
#  'question/232003701',
#  'question/230174132',
#  'question/233920279',
#  'question/229730110',
#  'question/228957203',
#  'question/234088877',
#  'question/228248071',
#  'question/228814617',
#  'question/231130850',
#  'question/229584208',
#  'question/233228077',
#  'question/219002078',
#  'question/228190994',
#  'question/231908824',
#  'question/230715741',
#  'question/233254177',
#  'question/233885073',
#  'question/231532928',
#  'question/233208288',
#  'question/234694753',
#  'question/231224454',
#  'question/230570625',
#  'question/229575778',
#  'question/229185252',
#  'question/227662952',
#  'question/227351486',
#  'question/231388949',
#  'question/231034047',
#  'question/229425186',
#  'question/228558803',
#  'question/228386346',
#  'question/228220172',
#  'question/214157677',
#  'question/227351752',
#  'question/224264863',
#  'question/232345917',
#  'question/232961867',
#  'question/229694292',
#  'question/229093644',
#  'question/227626178',
#  'question/228878964',
#  'question/234476431',
#  'question/231278949',
#  'question/233520081',
#  'question/227458322',
#  'question/221919119',
#  'question/229733724',
#  'question/234770190',
#  'question/233515700',
#  'question/233411757',
#  'question/232320529',
#  'question/233293105',
#  'question/233629518',
#  'question/229501008',
#  'question/229658941',
#  'question/230625552',
#  'question/227795913',
#  'question/227527905',
#  'question/233949143',
#  'question/229293438',
#  'question/233620732',
#  'question/232296363',
#  'question/234099889',
#  'question/228956536',
#  'question/228647812',
#  'question/231995912',
#  'question/228918580',
#  'question/227763169',
#  'question/231338783',
#  'question/229221732',
#  'question/231503682',
#  'question/226006731',
#  'question/232353156',
#  'question/225900792',
#  'question/229488777',
#  'question/228184252',
#  'question/231894810',
#  'question/231209696',
#  'question/230767797',
#  'question/227674234',
#  'question/232639483',
#  'question/232189733',
#  'question/233819806',
#  'question/231916651',
#  'question/230840500',
#  'question/229219561',
#  'question/233445263',
#  'question/228798061',
#  'question/228905644',
#  'question/234210123',
#  'question/232135810',
#  'question/228508509',
#  'question/227742028',
#  'question/232700140',
#  'question/234705184',
#  'question/232869502',
#  'question/232714212',
#  'question/232435778',
#  'question/231900237',
#  'question/227751339',
#  'question/232341598',
#  'question/228340841',
#  'question/227958399',
#  'question/234431546',
#  'question/229611890',
#  'question/234728007',
#  'question/229822423',
#  'question/232859193',
#  'question/231077608',
#  'question/228320972',
#  'question/233722800',
#  'question/229869790',
#  'question/230780928',
#  'question/233775748',
#  'question/230231373',
#  'question/230548526',
#  'question/228324046',
#  'question/234849296',
#  'question/233086937',
#  'question/234729037',
#  'question/231595186',
#  'question/234388588',
#  'question/233273457',
#  'question/230267373',
#  'question/229814633',
#  'question/228452768',
#  'question/233306969',
#  'question/231280636',
#  'question/230084602',
#  'question/229991767',
#  'question/234227950',
#  'question/234422855',
#  'question/231577517',
#  'question/228966414',
#  'question/228197951',
#  'question/232699534',
#  'question/234016558',
#  'question/233788352',
#  'question/229687126',
#  'question/229637731',
#  'question/228786810',
#  'question/234121089',
#  'question/234129309',
#  'question/231405762',
#  'question/230325063',
#  'question/230114111',
#  'question/233666126',
#  'question/233336395',
#  'question/231976995',
#  'question/230748907',
#  'question/231203682',
#  'question/229394678',
#  'question/230563104',
#  'question/227651685',
#  'question/229858487',
#  'question/228494298',
#  'question/230133888',
#  'question/229213890',
#  'question/234143714',
#  'question/233239042',
#  'question/229267635',
#  'question/229511164',
#  'question/229164161',
#  'question/232547227',
#  'question/233278829',
#  'question/231632584',
#  'question/227636109',
#  'question/234450540',
#  'question/230718412',
#  'question/228597091',
#  'question/214356853',
#  'question/230368740',
#  'question/232806753',
#  'question/232388527',
#  'question/232308416',
#  'question/234761115',
#  'question/230933197',
#  'question/230552414',
#  'question/234545224',
#  'question/232610504',
#  'question/231968491',
#  'question/231902712',
#  'question/230488342',
#  'question/229731897',
#  'question/228073490',
#  'question/234164313',
#  'question/232231914',
#  'question/232620033',
#  'question/230395443',
#  'question/228960094',
#  'question/230405172',
#  'question/234559337',
#  'question/228972077',
#  'question/230990878',
#  'question/228082484',
#  'question/234180650',
#  'question/232048920',
#  'question/229368844',
#  'question/232784615',
#  'question/234137665',
#  'question/231342429',
#  'question/228119166',
#  'question/223334351',
#  'question/232914315',
#  'question/231789214',
#  'question/230224447',
#  'question/228392016',
#  'question/227621173',
#  'question/231377120',
#  'question/230446212',
#  'question/227630567',
#  'question/231296774',
#  'question/234884111',
#  'question/232869937',
#  'question/231979139',
#  'question/231229135',
#  'question/228919581',
#  'question/228132813',
#  'question/233835746',
#  'question/233256984',
#  'question/231156367',
#  'question/229667212',
#  'question/231908372',
#  'question/233833251',
#  'question/229911801',
#  'question/229209199',
#  'question/227454520',
#  'question/227472529',
#  'question/233041973',
#  'question/232924219',
#  'question/234619524',
#  'question/230028792',
#  'question/229399507',
#  'question/234761537',
#  'question/234193150',
#  'question/233676430',
#  'question/232514661',
#  'question/231965983',
#  'question/232758111',
#  'question/234631520',
#  'question/234661041',
#  'question/230400464',
#  'question/230314445',
#  'question/228745227',
#  'question/228340505',
#  'question/228280991',
#  'question/233655902',
#  'question/229358029',
#  'question/232455611',
#  'question/233854515',
#  'question/232857635',
#  'question/229379772',
#  'question/234905165',
#  'question/231149578',
#  'question/232761217',
#  'question/233400692',
#  'question/229349700',
#  'question/234518452',
#  'question/232720686',
#  'question/232102818',
#  'question/229688789',
#  'question/234682036',
#  'question/233231386',
#  'question/233636870',
#  'question/233651094',
#  'question/231906688',
#  'question/233462963',
#  'question/228903905',
#  'question/232260666',
#  'question/227606953',
#  'question/229940660',
#  'question/230909117',
#  'question/234128996',
#  'question/229830320',
#  'question/232215801',
#  'question/231567189',
#  'question/229970565',
#  'question/228568475',
#  'question/229445627',
#  'question/234223731',
#  'question/225205043',
#  'question/230420304',
#  'question/234338516',
#  'question/230552157',
#  'question/232849794',
#  'question/234703493',
#  'question/234542375',
#  'question/233899042',
#  'question/231752298',
#  'question/230863782',
#  'question/231590703',
#  'question/228572706',
#  'question/230966670',
#  'question/229978984',
#  'question/215912026',
#  'question/231025485',
#  'question/228625332',
#  'question/229319561',
#  'question/234692396',
#  'question/234065530',
#  'question/232836936',
#  'question/233936573',
#  'question/231843600',
#  'question/232866828',
#  'question/234251783',
#  'question/232965396',
#  'question/233256174',
#  'question/233028475',
#  'question/227794060',
#  'question/233933433',
#  'question/234281214',
#  'question/227969594',
#  'question/227745076',
#  'question/232723954',
#  'question/230816185',
#  'question/233263560',
#  'question/232938438',
#  'question/230758378',
#  'question/232432618',
#  'question/233968741',
#  'question/233997490',
#  'question/234073266',
#  'question/233053539',
#  'question/228582149',
#  'question/231442549',
#  'question/230003676',
#  'question/228774567',
#  'question/231232862',
#  'question/234174460',
#  'question/231922052',
#  'question/230333113',
#  'question/233738897',
#  'question/234878477',
#  'question/231390525',
#  'question/230304184',
#  'question/229875985',
#  'question/228097353',
#  'question/228443215',
#  'question/227994720',
#  'question/231635933',
#  'question/227859140',
#  'question/230186878',
#  'question/233863213',
#  'question/232889090',
#  'question/234702667',
#  'question/232397394',
#  'question/228230469',
#  'question/232358085',
#  'question/231277900',
#  'question/232206577',
#  'question/229391354',
#  'question/227986619',
#  'question/227790461',
#  'question/230685061',
#  'question/227925430',
#  'question/228632507',
#  'question/232301982',
#  'question/228460178',
#  'question/232615409',
#  'question/234773094',
#  'question/230766900',
#  'question/230205477',
#  'question/232255634',
#  'question/230562862',
#  'question/228492306',
#  'question/228939246',
#  'question/227599287',
#  'question/230007738',
#  'question/231371816',
#  'question/230307989',
#  'question/234659711',
#  'question/233709204',
#  'question/228361429',
#  'question/227790355',
#  'question/232192832',
#  'question/234242355',
#  'question/228905944',
#  'question/229345086',
#  'question/232720035',
#  'question/228392041',
#  'question/234584480',
#  'question/231091409',
#  'question/214369494',
#  'question/232229259',
#  'question/231490677',
#  'question/233340546',
#  'question/230098243',
#  'question/231423422',
#  'question/234252660',
#  'question/230914523',
#  'question/230625456',
#  'question/232025746',
#  'question/230290711',
#  'question/229999907',
#  'question/227891212',
#  'question/229747351',
#  'question/229784535',
#  'question/231886079',
#  'question/233416888',
#  'question/233865952',
#  'question/234021725',
#  'question/228639378',
#  'question/227816069',
#  'question/233838222',
#  'question/229224093',
#  'question/231646197',
#  'question/233295899',
#  'question/230940256',
#  'question/232258999',
#  'question/232309211',
#  'question/231455138',
#  'question/229313007',
#  'question/228609701',
#  'question/233865363',
#  'question/229390686',
#  'question/227644343',
#  'question/231813391',
#  'question/230363254',
#  'question/231860158',
#  'question/229139726',
#  'question/232985333',
#  'question/226524102',
#  'question/232558893',
#  'question/228681281',
#  'question/230674173',
#  'question/231737056',
#  'question/231899446',
#  'question/228672842',
#  'question/228220757',
#  'question/234012625',
#  'question/230333303',
#  'question/232970575',
#  'question/230045678',
#  'question/230561443',
#  'question/229966896',
#  'question/232250498',
#  'question/231043249',
#  'question/228785350',
#  'question/232017443',
#  'question/232924706',
#  'question/229475456',
#  'question/231930604',
#  'question/230050750',
#  'question/229403456',
#  'question/233368158',
#  'question/227548238',
#  'question/234916031',
#  'question/232439203',
#  'question/232290467',
#  'question/228818232',
#  'question/231026297',
#  'question/228627398',
#  'question/229507304',
#  'question/233681671',
#  'question/229429079',
#  'question/227643704',
#  'question/229143819',
#  'question/229500530',
#  'question/229982526',
#  'question/233519233',
#  'question/232615071',
#  'question/227892817',
#  'question/229860892',
#  'question/234501138',
#  'question/234671234',
#  'question/234134867',
#  'question/232343892',
#  'question/231896186',
#  'question/234686116',
#  'question/230611077',
#  'question/229598383',
#  'question/234833718',
#  'question/234270745',
#  'question/234878287',
#  'question/231877091',
#  'question/231593713',
#  'question/232459427',
#  'question/230254515',
#  'question/233449497',
#  'question/232249587',
#  'question/233830444',
#  'question/233236803',
#  'question/230139592',
#  'question/231261601',
#  'question/228152020',
#  'question/231808085',
#  'question/233951829',
#  'question/231966840',
#  'question/232113424',
#  'question/219690050',
#  'question/234940560',
#  'question/233102383',
#  'question/232678113',
#  'question/228500940',
#  'question/234858972',
#  'question/233730488',
#  'question/234864142',
#  'question/233821035',
#  'question/233298334',
#  'question/233639162',
#  'question/231563578',
#  'question/229890418',
#  'question/232734373',
#  'question/229618556',
#  'question/230856487',
#  'question/230031382',
#  'question/229019811',
#  'question/234846759',
#  'question/234029145',
#  'question/228793754',
#  'question/231178859',
#  'question/228971019',
#  'question/228640253',
#  'question/228368884',
#  'question/232168863',
#  'question/230873968',
#  'question/232488362',
#  'question/229926091',
#  'question/229184415',
#  'question/216279364',
#  'question/234243413',
#  'question/228584310',
#  'question/228307788',
#  'question/228054163',
#  'question/229697389',
#  'question/227743510',
#  'question/229909061',
#  'question/233428118',
#  'question/232422038',
#  'question/230054336',
#  'question/232621023',
#  'question/231661533',
#  'question/231721545',
#  'question/232910941',
#  'question/228160944',
#  'question/229616303',
#  'question/233620253',
#  'question/233276199',
#  'question/231895537',
#  'question/228301377',
#  'question/230059538',
#  'question/227827941',
#  'question/227853527',
#  'question/233421337',
#  'question/231897133',
#  'question/228009286',
#  'question/229830813',
#  'question/228333029',
#  'question/234392026',
#  'question/231744080',
#  'question/234407687',
#  'question/234042582',
#  'question/233229919',
#  'question/230770819',
#  'question/234351458',
#  'question/229397736',
#  'question/232926153',
#  'question/233389758',
#  'question/232851637',
#  'question/230657676',
#  'question/230740580',
#  'question/234612746',
#  'question/230556471',
#  'question/228753043',
#  'question/232713772',
#  'question/227419156',
#  'question/231772017',
#  'question/233727435',
#  'question/233925691',
#  'question/230124273',
#  'question/229841497',
#  'question/234465042',
#  'question/228833125',
#  'question/227628196',
#  'question/234175623',
#  'question/231965062',
#  'question/217870329',
#  'question/233719036',
#  'question/229584853',
#  'question/228145720',
#  'question/230275482',
#  'question/233843931',
#  'question/234733305',
#  'question/231544957',
#  'question/230765754',
#  'question/234563611',
#  'question/227876921',
#  'question/229412508',
#  'question/231481827',
#  'question/229413142',
#  'question/233133125',
#  'question/229846307',
#  'question/227874066',
#  ...]

# %%
header = ['Quest','Review','Popular','Another','Questslink']
with open('Mailreview.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    for i in (1,len(unique_quest)-1):
        writer.writerow(get_reviews(unique_quest[i]))
file = pd.read_csv('Mailreview.csv')
file
# Out:
#                   Quest                                             Review  \
# 0  Помогите найти фильм                             Найти фильм помогите\n
# 1  Помогите найти фильм  Друзья, помогите найти фильм по кадрам секс-сц...
#
#                                              Popular        Another  \
# 0                      Фильмографию Бельмондо листай             []
# 1  может я плюю на твою могилу или как там. одна ...  ['это порно']
#
#                                  Questslink
# 0  https://otvet.mail.ru/question/228264278
# 1  https://otvet.mail.ru/question/228219080
